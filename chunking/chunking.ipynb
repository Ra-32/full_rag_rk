# %%
import os
from langchain_text_splitters import RecursiveCharacterTextSplitter,CharacterTextSplitter

# %%
from langchain_text_splitters import (
    CharacterTextSplitter,
    RecursiveCharacterTextSplitter
)

# ============================================================
# SAMPLE TEXT
# ============================================================

text = """
The police investigated a robbery that happened at a local jewelry store on Saturday night. After checking the security cameras, they identified a man named John. John was arrested the next morning after the police found several pieces of stolen jewelry inside his house.

The investigators later discovered that John had entered the store shortly before closing time. He had previously worked at the same store and knew where the most expensive jewelry was kept. The police also found fingerprints near the display cabinets that matched John's fingerprints.

During the investigation, the police interviewed several witnesses who had seen John near the store on the night of the robbery. One witness reported seeing John carrying a black bag when he left the building. The investigators also recovered messages between John and another person discussing the stolen jewelry.

The police later identified the second person as Michael. Michael admitted that he had helped John hide the stolen jewelry after the robbery. The police recovered the remaining jewelry from a storage room and returned it to the store owner after completing the investigation.
"""


# ============================================================
# 1. FIXED-SIZE CHUNKING
# ============================================================

fixed = CharacterTextSplitter(
    separator="",
    chunk_size=100,
    chunk_overlap=0,
    length_function=len
)

print("=" * 70)
print("1. FIXED-SIZE CHUNKING")
print("=" * 70)

fixed_chunks = fixed.split_text(text)

print(f"Total chunks: {len(fixed_chunks)}")

for i, chunk in enumerate(fixed_chunks, 1):
    print(f"\nChunk {i}")
    print("-" * 50)
    print(chunk)
    print(f"\nCharacters: {len(chunk)}")


# ============================================================
# 2. PARAGRAPH-BASED CHUNKING
# ============================================================

paragraph = CharacterTextSplitter(
    separator="\n\n",
    chunk_size=100,
    chunk_overlap=0,
    length_function=len
)

print("\n\n")
print("=" * 70)
print("2. PARAGRAPH-BASED CHUNKING")
print("=" * 70)

paragraph_chunks = paragraph.split_text(text)

print(f"Total chunks: {len(paragraph_chunks)}")

for i, chunk in enumerate(paragraph_chunks, 1):
    print(f"\nChunk {i}")
    print("-" * 50)
    print(chunk)
    print(f"\nCharacters: {len(chunk)}")


# ============================================================
# 3. RECURSIVE CHUNKING
# ============================================================

recursive = RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=20,
    length_function=len,
    separators=["\n\n", "\n", ". ", " ", ""]
)

print("\n\n")
print("=" * 70)
print("3. RECURSIVE CHUNKING")
print("=" * 70)

recursive_chunks = recursive.split_text(text)

print(f"Total chunks: {len(recursive_chunks)}")

for i, chunk in enumerate(recursive_chunks, 1):
    print(f"\nChunk {i}")
    print("-" * 50)
    print(chunk)
    print(f"\nCharacters: {len(chunk)}")


# ============================================================
# SUMMARY
# ============================================================

print("\n\n")
print("=" * 70)
print("SUMMARY")
print("=" * 70)

print(f"Fixed-size chunks      : {len(fixed_chunks)}")
print(f"Paragraph chunks       : {len(paragraph_chunks)}")
print(f"Recursive chunks       : {len(recursive_chunks)}")
# Out:
# Created a chunk of size 272, which is longer than the specified 100
# Created a chunk of size 285, which is longer than the specified 100
# Created a chunk of size 314, which is longer than the specified 100
# ======================================================================
# 1. FIXED-SIZE CHUNKING
# ======================================================================
# Total chunks: 12
#
# Chunk 1
# --------------------------------------------------
# The police investigated a robbery that happened at a local jewelry store on Saturday night. After c
#
# Characters: 99
#
# Chunk 2
# --------------------------------------------------
# hecking the security cameras, they identified a man named John. John was arrested the next morning a
#
# Characters: 100
#
# Chunk 3
# --------------------------------------------------
# fter the police found several pieces of stolen jewelry inside his house.
#
# The investigators later di
#
# Characters: 100
#
# Chunk 4
# --------------------------------------------------
# scovered that John had entered the store shortly before closing time. He had previously worked at th
#
# Characters: 100
#
# Chunk 5
# --------------------------------------------------
# e same store and knew where the most expensive jewelry was kept. The police also found fingerprints
#
# Characters: 99
#
# Chunk 6
# --------------------------------------------------
# near the display cabinets that matched John's fingerprints.
#
# During the investigation, the police in
#
# Characters: 100
#
# Chunk 7
# --------------------------------------------------
# terviewed several witnesses who had seen John near the store on the night of the robbery. One witnes
#
# Characters: 100
#
# Chunk 8
# --------------------------------------------------
# s reported seeing John carrying a black bag when he left the building. The investigators also recove
#
# Characters: 100
#
# Chunk 9
# --------------------------------------------------
# red messages between John and another person discussing the stolen jewelry.
#
# The police later identi
#
# Characters: 100
#
# Chunk 10
# --------------------------------------------------
# fied the second person as Michael. Michael admitted that he had helped John hide the stolen jewelry
#
# Characters: 99
#
# Chunk 11
# --------------------------------------------------
# after the robbery. The police recovered the remaining jewelry from a storage room and returned it to
#
# Characters: 100
#
# Chunk 12
# --------------------------------------------------
# the store owner after completing the investigation.
#
# Characters: 51
#
#
#
# ======================================================================
# 2. PARAGRAPH-BASED CHUNKING
# ======================================================================
# Total chunks: 4
#
# Chunk 1
# --------------------------------------------------
# The police investigated a robbery that happened at a local jewelry store on Saturday night. After checking the security cameras, they identified a man named John. John was arrested the next morning after the police found several pieces of stolen jewelry inside his house.
#
# Characters: 271
#
# Chunk 2
# --------------------------------------------------
# The investigators later discovered that John had entered the store shortly before closing time. He had previously worked at the same store and knew where the most expensive jewelry was kept. The police also found fingerprints near the display cabinets that matched John's fingerprints.
#
# Characters: 285
#
# Chunk 3
# --------------------------------------------------
# During the investigation, the police interviewed several witnesses who had seen John near the store on the night of the robbery. One witness reported seeing John carrying a black bag when he left the building. The investigators also recovered messages between John and another person discussing the stolen jewelry.
#
# Characters: 314
#
# Chunk 4
# --------------------------------------------------
# The police later identified the second person as Michael. Michael admitted that he had helped John hide the stolen jewelry after the robbery. The police recovered the remaining jewelry from a storage room and returned it to the store owner after completing the investigation.
#
# Characters: 275
#
#
#
# ======================================================================
# 3. RECURSIVE CHUNKING
# ======================================================================
# Total chunks: 16
#
# Chunk 1
# --------------------------------------------------
# The police investigated a robbery that happened at a local jewelry store on Saturday night
#
# Characters: 90
#
# Chunk 2
# --------------------------------------------------
# . After checking the security cameras, they identified a man named John
#
# Characters: 71
#
# Chunk 3
# --------------------------------------------------
# . John was arrested the next morning after the police found several pieces of stolen jewelry inside
#
# Characters: 99
#
# Chunk 4
# --------------------------------------------------
# jewelry inside his house.
#
# Characters: 25
#
# Chunk 5
# --------------------------------------------------
# The investigators later discovered that John had entered the store shortly before closing time
#
# Characters: 94
#
# Chunk 6
# --------------------------------------------------
# . He had previously worked at the same store and knew where the most expensive jewelry was kept
#
# Characters: 95
#
# Chunk 7
# --------------------------------------------------
# . The police also found fingerprints near the display cabinets that matched John's fingerprints.
#
# Characters: 96
#
# Chunk 8
# --------------------------------------------------
# During the investigation, the police interviewed several witnesses who had seen John near the store
#
# Characters: 99
#
# Chunk 9
# --------------------------------------------------
# John near the store on the night of the robbery
#
# Characters: 47
#
# Chunk 10
# --------------------------------------------------
# . One witness reported seeing John carrying a black bag when he left the building
#
# Characters: 81
#
# Chunk 11
# --------------------------------------------------
# . The investigators also recovered messages between John and another person discussing the stolen
#
# Characters: 97
#
# Chunk 12
# --------------------------------------------------
# the stolen jewelry.
#
# Characters: 19
#
# Chunk 13
# --------------------------------------------------
# The police later identified the second person as Michael
#
# Characters: 56
#
# Chunk 14
# --------------------------------------------------
# . Michael admitted that he had helped John hide the stolen jewelry after the robbery
#
# Characters: 84
#
# Chunk 15
# --------------------------------------------------
# . The police recovered the remaining jewelry from a storage room and returned it to the store owner
#
# Characters: 99
#
# Chunk 16
# --------------------------------------------------
# to the store owner after completing the investigation.
#
# Characters: 54
#
#
#
# ======================================================================
# SUMMARY
# ======================================================================
# Fixed-size chunks      : 12
# Paragraph chunks       : 4
# Recursive chunks       : 16
